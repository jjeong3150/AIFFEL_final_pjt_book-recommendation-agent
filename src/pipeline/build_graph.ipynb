# %%
# !git clone https://github.com/jjeong3150/AIFFEL_final_pjt_book-recommendation-agent
# Out:
# Cloning into 'AIFFEL_final_pjt_book-recommendation-agent'...
# remote: Enumerating objects: 357, done.
# remote: Counting objects: 100% (87/87), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 357 (delta 49), reused 0 (delta 0), pack-reused 270 (from 1)
# Receiving objects: 100% (357/357), 25.88 MiB | 13.24 MiB/s, done.
# Resolving deltas: 100% (175/175), done.

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# %run /content/AIFFEL_final_pjt_book-recommendation-agent/src/profiling/user_profiling_demo_jc.ipynb
# %run /content/AIFFEL_final_pjt_book-recommendation-agent/src/profiling/advanced_profiling_demo.ipynb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 kB 23.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 78.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.6/99.6 kB 11.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 69.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 30.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 83.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 44.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 76.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 8.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.9/170.9 kB 18.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 22.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 8.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.42.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-sdk<1.39.0,>=1.36.0, but you have opentelemetry-sdk 1.42.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-exporter-otlp-proto-common==1.38.0, but you have opentelemetry-exporter-otlp-proto-common 1.42.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-proto==1.38.0, but you have opentelemetry-proto 1.42.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-sdk~=1.38.0, but you have opentelemetry-sdk 1.42.1 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.42.1 which is incompatible.

# %%
# %run /content/AIFFEL_final_pjt_book-recommendation-agent/src/rag/simple_rag/simple_rag.ipynb
# %run /content/AIFFEL_final_pjt_book-recommendation-agent/src/rag/query_transformations/query_transformations_rag.ipynb
# Out:
# fatal: destination path 'AIFFEL_final_pjt_book-recommendation-agent' already exists and is not an empty directory.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 398.1/398.1 kB 12.9 MB/s eta 0:00:00
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/15.8k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/54.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/687 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/444 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]
# [LocalReranker] 캐시 로드 실패 (Repo id must be in the form 'repo_name' or 'namespace/repo_name': '/content/drive/MyDrive/aiffel_final_pjt/models/BAAI_bge-reranker-v2-m3'. Use `repo_type` argument if needed.), HuggingFace에서 다운로드
# config.json:   0%|          | 0.00/795 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/393 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# [LocalReranker] 캐시 저장 완료: /content/drive/MyDrive/aiffel_final_pjt/models/BAAI_bge-reranker-v2-m3

# %%
# %run /content/AIFFEL_final_pjt_book-recommendation-agent/src/tools/api_tool_calling.ipynb
# Out:
# /tmp/ipykernel_1251/896750007.py:41: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent_executor = create_react_agent(

# %%
# ============================================================
# 초기 상태
# ============================================================
import uuid
from langchain_openai import ChatOpenAI

llm          = ChatOpenAI(model="gpt-4o-mini", temperature=0.7)
memory_store = MemoryStore(persist_directory="./chroma_db")
nodes = create_nodes(llm, memory_store)

session_id = str(uuid.uuid4())[:8]


initial_state = {
    # 메모리 필드
    "messages": [],
    "session_id": session_id,
    "phase": Phase.SLOT_FILLING,
    "turn_count": 0,
    "user_profile": UserProfile(),
    "current_slot": "reading_goal",
    "similar_profiles": None,
    "matched_profile_id": None,
    "book_experiences": [],
    "asked_book_experience": False,
    "summary": "",
    "reflection": "",
    "links": [],
    "ai_response": "",

    # RAG 필드 추가
    "retrieved_books": [],
    "recommendations": [],
    "genre_filter": [],

    # Tool Calling
    "availability_results" : None,
}

config     = {"configurable": {"thread_id": f"thread_{session_id}"}}

# %%
from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import StateGraph, END


graph = StateGraph(GraphState)

# 프로파일링 노드
graph.add_node("generate_slot_question",  nodes["generate_slot_question"])
graph.add_node("process_slot_answer",     nodes["process_slot_answer"])
graph.add_node("search_similar_profiles", nodes["search_similar_profiles"])
graph.add_node("process_match_confirm",   nodes["process_match_confirm"])
graph.add_node("ask_book_experience",     nodes["ask_book_experience"])
graph.add_node("process_book_experience", nodes["process_book_experience"])
graph.add_node("generate_summary",        nodes["generate_summary"])
graph.add_node("perform_reflection",      nodes["perform_reflection"])

# RAG 노드
graph.add_node("extract_genre",       extract_genre_node)
graph.add_node("query_transform_rag", query_transform_rag_node)
graph.add_node("rag_llm",             rag_llm_node)


# Tool Calling 노드
graph.add_node("api_tool_calling", api_tool_calling_node)

# 프로파일링 엣지
graph.set_entry_point("generate_slot_question")
graph.add_edge("generate_slot_question", "process_slot_answer")
graph.add_conditional_edges("process_slot_answer", route_after_slot_processing,
    {"generate_slot_question": "generate_slot_question",
     "search_similar_profiles": "search_similar_profiles",
     "ask_book_experience":     "ask_book_experience"})
graph.add_conditional_edges("search_similar_profiles", route_after_similar_search,
    {"process_match_confirm":   "process_match_confirm",
     "generate_slot_question":  "generate_slot_question"})
graph.add_conditional_edges("process_match_confirm", route_after_match_confirm,
    {"ask_book_experience":     "ask_book_experience",
     "generate_slot_question":  "generate_slot_question"})
graph.add_edge("ask_book_experience",    "process_book_experience")
graph.add_conditional_edges("process_book_experience", route_after_book_experience,
    {"ask_book_experience":  "ask_book_experience",
     "generate_summary":     "generate_summary"})
graph.add_edge("generate_summary", "perform_reflection")

# 연결 지점 (profiling -> rag)
graph.add_edge("perform_reflection", "extract_genre")

# RAG 엣지
graph.add_edge("extract_genre",       "query_transform_rag")
graph.add_edge("query_transform_rag", "rag_llm")

# 연결 지점 (memory -> tool calling)
graph.add_edge("rag_llm", "api_tool_calling")
graph.add_edge("api_tool_calling",    END)


app = graph.compile(
    checkpointer=MemorySaver(),
    interrupt_before=[
        "process_slot_answer",
        "process_match_confirm",
        "process_book_experience",
    ],
)

# %%
app

# %%
# # ============================================================
# # 테스트 실행 (단독 테스트용)
# # ============================================================

# import asyncio
# from langchain_core.messages import HumanMessage, AIMessage

# def _print_final_profile(state):
#     profile = state.get("user_profile", UserProfile())
#     experiences = state.get("book_experiences", [])
#     summary = state.get("summary", "")
#     reflection = state.get("reflection", "")

#     print("\n📋 사용자 프로필:")
#     for name, info in profile.to_display_dict().items():
#         status_icon = {"filled": "✅", "unclear": "❓", "empty": "⬜"}
#         icon = status_icon.get(info["status"], "⬜")
#         print(f"  {icon} {name}: {info['value'] or '(없음)'} [{info['status']}]")

#     if experiences:
#         print("\n📖 독서 경험:")
#         for exp in experiences:
#             print(f"  - {exp.book_name}: {exp.impression} {exp.context}")

#     print(f"\n📝 요약: {summary}")
#     print(f"\n💡 인사이트: {reflection}")


# def _extract_ai_responses(state):
#     messages = state.get("messages", [])
#     responses = []
#     for msg in reversed(messages):
#         if isinstance(msg, HumanMessage) or getattr(msg, "type", None) == "human":
#             break
#         if isinstance(msg, AIMessage) or getattr(msg, "type", None) == "ai":
#             responses.append(msg.content)
#     responses.reverse()
#     return responses


# async def test_conversation():
#     # ── 1단계: 초기 실행 ──
#     # generate_slot_question 실행 → process_slot_answer 직전에서 interrupt
#     result = await app.ainvoke(initial_state, config=config)

#     # AI 응답 출력
#     for resp in _extract_ai_responses(result):
#         print(f"🤖 큐레이터: {resp}\n")

#     # ── 2단계: 대화 루프 ──
#     while True:
#         user_input = input("👤 사용자: ").strip()
#         if user_input.lower() in ("quit", "exit", "종료"):
#             print("\n세션을 종료합니다. 감사합니다!")
#             break

#         # 사용자 메시지를 상태에 주입
#         app.update_state(config, {"messages": [HumanMessage(content=user_input)]})

#         # interrupt 지점에서 resume → process 노드 실행 → 다음 question → 다시 interrupt (또는 END)
#         result = await app.ainvoke(None, config=config)

#         for resp in _extract_ai_responses(result):
#             print(f"🤖 큐레이터: {resp}\n")

#         # 완료 체크 (perform_reflection → END 도달 시 interrupt 없이 완료됨)
#         snapshot = app.get_state(config)
#         if snapshot.next == ():
#             print("\n" + "=" * 60)
#             print("✅ 프로파일링 완료!")
#             print("=" * 60)
#             _print_final_profile(snapshot.values)  # ← 추가
#             break

# await test_conversation()
# Out:
# 🤖 큐레이터: 책을 읽고 싶은 마음이 드셨군요! 혹시 특별한 목표나 이유가 있으신가요? 예를 들어, 새로운 지식을 쌓고 싶거나, 취미로 즐기고 싶다거나 하는 것처럼요.
#
# 👤 사용자: 쉬는 시간에 소설을 읽고 싶어. 간단히 SF 장르의 소설을 읽을까 생각중이야
# WARNING:langgraph.checkpoint.serde.jsonplus:Deserializing unregistered type __main__.Phase from checkpoint. This will be blocked in a future version. Set LANGGRAPH_STRICT_MSGPACK=true to block now, or add to allowed_msgpack_modules to allow explicitly: [('__main__', 'Phase')]
# WARNING:langgraph.checkpoint.serde.jsonplus:Deserializing unregistered type __main__.SlotStatus from checkpoint. This will be blocked in a future version. Set LANGGRAPH_STRICT_MSGPACK=true to block now, or add to allowed_msgpack_modules to allow explicitly: [('__main__', 'SlotStatus')]
# WARNING:langgraph.checkpoint.serde.jsonplus:Deserializing unregistered type __main__.UserProfile from checkpoint. This will be blocked in a future version. Set LANGGRAPH_STRICT_MSGPACK=true to block now, or add to allowed_msgpack_modules to allow explicitly: [('__main__', 'UserProfile')]
# /root/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:01<00:00, 44.8MiB/s]
# 🤖 큐레이터: 그렇군요! 쉬는 시간에 간단한 SF 소설을 읽으려는 마음이 멋지네요. 혹시 너무 복잡하지 않으면서도 흥미로운 이야기를 원하시나요, 아니면 조금 더 깊이 있는 내용을 원하실까요?
#
# 👤 사용자: 좀 복잡하고 길어도 좋아. 두고두고 읽으면 되니까
# 🤖 큐레이터: 최근에 읽었던 SF 소설이 있다면, 어떤 제목인지와 그 책에 대한 간단한 소감을 공유해 주실 수 있나요? 쉬는 시간에 간단히 읽기 좋은 책을 찾고 있는데, 추천해 주시면 좋겠습니다!
#
# 👤 사용자: 최근 프로젝트 헤일메리를 읽었어. 외계인과 함꼐 어려움을 헤쳐나가는 주인공과 로키가 굉장히 아름다워 보였어
# 추출된 장르: ['소설']
#
# [Query Transformations]
#   [Step-back]  : 깊이 있는 서사와 복잡한 세계관을 가진 SF 소설을 찾아보세요. 외계인과의 관계를 탐구하는 주제를 중심으로, 감정적으로도 풍부한 이야기를 제공하는 작품을 추천드립니다.
#   [Rewritten]  : 쉬는 시간에 읽기 좋은 복잡하고 긴 이야기를 가진 심도 있는 SF 소설을 찾고 있습니다. 외계인과의 관계를 탐구하며 감동을 주는 작품을 추천해주세요.
#   [Sub-queries]: ['쉬는 시간에 읽기 좋은 복잡하고 긴 이야기를 가진 심도 있는 SF 소설을 찾고 있습니다.', '외계인과의 관계를 탐구하며 감동을 주는 작품을 찾고 있습니다.', '독특한 세계관을 가진 SF 소설 중에서 인물의 내면적 갈등이 잘 드러나는 작품을 고려하고 있습니다.']
#
# [Reranking 결과]
#   score: 0.0910 | 영원한 전쟁 - 폰 북스 9
#   score: 0.0378 | 위그드라실의 여신들 - 가옥 쇼-트 22
#   score: 0.0106 | 새드엔딩에 안녕을
#   score: 0.0103 | 키워드로 읽는 SF
#   score: 0.0096 | 블루스카이 3 - 피로 얼룩진 혁명군
#   score: 0.0094 | 토털호러 = Total Horror
#   score: 0.0047 | 일대마도 3 - 무적
#   score: 0.0047 | 여행 그리고 파리 - Travel and Paris
#   score: 0.0047 | 가을바다 사람들
#   score: 0.0035 | 타임리미트 2
#
# ▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼
# 📡 [도서관 목록 조회 API 통신 로그]
# 👉 실제 호출된 URL: http://data4library.kr/api/libSrch?authKey=%0916424b20e4393e27541144ae9873e2dd63a08d7a4eb6b73942c93b4d54f4241f&region=11&dtl_region=11230&pageSize=3&format=json
# ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲
#
#
# ▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼
# 📡 [ISBN + 표지 URL 검색	API 통신 로그]
# 👉 실제 호출된 URL: https://openapi.naver.com/v1/search/book.json?query=%EC%98%81%EC%9B%90%ED%95%9C+%EC%A0%84%EC%9F%81&display=1
# ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲
#
#
# ▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼
# 📡 [ISBN + 표지 URL 검색	API 통신 로그]
# 👉 실제 호출된 URL: https://openapi.naver.com/v1/search/book.json?query=%EC%9C%84%EA%B7%B8%EB%93%9C%EB%9D%BC%EC%8B%A4%EC%9D%98+%EC%97%AC%EC%8B%A0%EB%93%A4&display=1
# ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲
#
#
# ▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼
# 📡 [ISBN + 표지 URL 검색	API 통신 로그]
# 👉 실제 호출된 URL: https://openapi.naver.com/v1/search/book.json?query=%EC%83%88%EB%93%9C%EC%97%94%EB%94%A9%EC%97%90+%EC%95%88%EB%85%95%EC%9D%84&display=1
# ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲
#
#
# ▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼
# 📡 [대출 가능 여부 조회 API 통신 로그]
# 👉 실제 호출된 URL: http://data4library.kr/api/bookExist?authKey=%0916424b20e4393e27541144ae9873e2dd63a08d7a4eb6b73942c93b4d54f4241f&libCode=111533&isbn13=9791187514213&format=json
# ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲
#
#
# ▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼
# 📡 [대출 가능 여부 조회 API 통신 로그]
# 👉 실제 호출된 URL: http://data4library.kr/api/bookExist?authKey=%0916424b20e4393e27541144ae9873e2dd63a08d7a4eb6b73942c93b4d54f4241f&libCode=111070&isbn13=9791193024287&format=json
# ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲
#
#
# ▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼
# 📡 [대출 가능 여부 조회 API 통신 로그]
# 👉 실제 호출된 URL: http://data4library.kr/api/bookExist?authKey=%0916424b20e4393e27541144ae9873e2dd63a08d7a4eb6b73942c93b4d54f4241f&libCode=111526&isbn13=9791158881641&format=json
# ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲
# WARNING:langgraph.checkpoint.serde.jsonplus:Deserializing unregistered type __main__.BookExperience from checkpoint. This will be blocked in a future version. Set LANGGRAPH_STRICT_MSGPACK=true to block now, or add to allowed_msgpack_modules to allow explicitly: [('__main__', 'BookExperience')]
# 🤖 큐레이터: 프로필 분석이 완료되었습니다!
#
# 📋 요약: 사용자는 쉬는 시간에 읽기 위해 SF 소설을 찾고 있으며, 간단한 형식보다는 복잡하고 긴 이야기를 선호합니다. 최근 읽은 "프로젝트 헤일메리"에서 외계인과의 관계를 통해 느낀 감동이 인상적이었습니다. 따라서, 깊이 있는 내용을 갖춘 SF 소설을 추천하는 것이 좋겠습니다.
#
# 💡 인사이트: 사용자는 현재 SF 소설을 통해 긴장감과 감동을 느끼고자 하며, 특히 복잡한 이야기를 통해 깊이 있는 경험을 추구합니다. 독서 스타일은 간단히 읽고자 하는 경향이 있지만, 내용의 깊이를 중시하는 경향이 여전히 존재하여, 이는 사용자의 독서 취향을 더욱 복잡하게 만듭니다. 따라서, SF 장르 내에서 복잡한 플롯을 가진 작품을 추천하는 것이 사용자의 욕구를 충족시킬 수 있을 것입니다.
#
# 🤖 큐레이터: [
#     {
#         "title": "영원한 전쟁 - 폰 북스 9",
#         "author": "조 홀드먼",
#         "isbn": "9788972594345",
#         "book_intro": "SF의고전.면작들을 엄선하여 깔끔한 번역으로 선보이는 SF 시리즈물이다. 국내에는 과학소설의 계층이 얇아 SF소설이 활성화되지 않았다. 그런와중에서도 시공 그리폰 북스 는 SF 매...",
#         "cate_depth1": "소설",
#         "reason": "복잡하고 긴 이야기를 선호하는 사용자에게 SF의 고전으로 깊이 있는 서사를 제공하는 '영원한 전쟁'은 외계인과의 관계 및 전쟁을 다룬 복잡한 내용이 매력적입니다."
#     },
#     {
#         "title": "위그드라실의 여신들 - 가옥 쇼-트 22",
#         "author": "해도연",
#         "isbn": "9791193024287",
#         "book_intro": "과학에 목말라하는 SF 독자를 위한 하드 SF 단편집 천문학 박사 현직 연구원인 작가가 심도 깊게 그리는 다음 세기의 태양계 SF 독자는 과학에 대한 갈증을 품고 있다. 과학 이론...",
#         "cate_depth1": "소설",
#         "reason": "위그드라실의 여신들은 과학과 SF가 조화롭게 어우러져 심도 깊은 이야기를 제공하므로, 외계인과의 관계에서 느낀 감동을 더욱 깊이 있게 탐구할 수 있는 기회를 제공합니다."
#     },
#     {
#         "title": "새드엔딩에 안녕을",
#         "author": "조현",
#         "isbn": "9791187514213",
#         "book_intro": "누군가를 위하여 시를 읊고 거짓말을 지어내며 기도를 바치는 이들의 이야기를 통해 우리에게 무한한 삶의 우주를 열어주는 우주행 차표 같은 소설들 새드엔딩에 안녕을 은 범상한 이야기가...",
#         "cate_depth1": "소설",
#         "reason": "복잡한 서사와 감정을 다루는 이 소설은 사용자에게 깊이 있는 이야기와 감동을 선사하며, SF 소설을 통한 삶의 우주를 탐구하는 데 적합한 선택이 될 것입니다."
#     }
# ]
#
# 🤖 큐레이터: ---
# 📚 영원한 전쟁 | 조 홀드먼
# ![영원한 전쟁](https://shopping-phinf.pstatic.net/main_3250691/32506915863.20251231073530.jpg)
#
# ✏️ 추천 이유
# 복잡하고 긴 이야기를 선호하는 사용자에게 SF의 고전으로 깊이 있는 서사를 제공하는 '영원한 전쟁'은 외계인과의 관계 및 전쟁을 다룬 복잡한 내용이 매력적입니다.
#
# 📍 대출 가능 여부
# - 강남구립개포하늘꿈도서관: (미소장)
#
# ---
# 📚 위그드라실의 여신들 | 해도연
# ![위그드라실의 여신들](https://shopping-phinf.pstatic.net/main_4265728/42657286621.20260331093933.jpg)
#
# ✏️ 추천 이유
# 위그드라실의 여신들은 과학과 SF가 조화롭게 어우러져 심도 깊은 이야기를 제공하므로, 외계인과의 관계에서 느낀 감동을 더욱 깊이 있게 탐구할 수 있는 기회를 제공합니다.
#
# 📍 대출 가능 여부
# - 강남구립논현도서관: (미소장)
#
# ---
# 📚 새드엔딩에 안녕을 | 조현
# ![새드엔딩에 안녕을](https://shopping-phinf.pstatic.net/main_3244525/32445253982.20260331120927.jpg)
#
# ✏️ 추천 이유
# 복잡한 서사와 감정을 다루는 이 소설은 사용자에게 깊이 있는 이야기와 감동을 선사하며, SF 소설을 통한 삶의 우주를 탐구하는 데 적합한 선택이 될 것입니다.
#
# 📍 대출 가능 여부
# - 강남구립논현문화마루도서관: (미소장)
#
# ---
#
# ✅ 완료!
